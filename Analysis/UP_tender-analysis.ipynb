# %%
import pandas as pd
import glob
import os

# %%
all_tender_path = r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Sources/TENDERS/data/all_tenders.csv'

# %%
#all_tender_path = r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Sources\TENDERS\data/monthly_tenders'
all_tender_path = r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Sources/TENDERS/data/all_tenders.csv'

monthly_files = glob.glob(os.path.join(all_tender_path, '*.csv'))
up_tenders = pd.concat([pd.read_csv(f) for f in monthly_files], ignore_index=True)
# ensure Contract Date is datetime, then extract year_month
up_tenders['year_month'] = pd.to_datetime(up_tenders['Contract Date'], errors='coerce')
up_tenders['year_month'] = up_tenders['year_month'].dt.strftime('%Y_%m')
up_tenders.to_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Sources\TENDERS\data\all_UP_tenders.csv', index=False)
#up_tenders = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Sources\TENDERS\data\floodtenders_blockgeotagged.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 all_tender_path = r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Sources/TENDERS/data/all_tenders.csv'
#       4 monthly_files = glob.glob(os.path.join(all_tender_path, '*.csv'))
# ----> 5 up_tenders = pd.concat([pd.read_csv(f) for f in monthly_files], ignore_index=True)
#       6 # ensure Contract Date is datetime, then extract year_month
#       7 up_tenders['year_month'] = pd.to_datetime(up_tenders['Contract Date'], errors='coerce')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
# ...

# %%
up_tenders = pd.read_csv(all_tender_path)
up_tenders = up_tenders.loc[up_tenders['Status'] == 'Accepted-AOC']
up_tenders
# Out:
# /var/folders/mn/tyjcr2q91wz11fzw0ttcj3780000gn/T/ipykernel_83748/2598409411.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   up_tenders = pd.read_csv(all_tender_path)
#                  Tender ID                           tender_externalreference  \
# 34     2018_UPIDC_269394_6                                      01/EE/2018-19
# 35     2018_UPIDC_281416_3                                      04/EE/2018-19
# 36     2018_UPIDC_287991_6                                      07/EE/2018-19
# 37     2019_CEUAZ_374005_1  2111 /SE Tender/Azamgarh Circle /19 DT. 09/08/...
# 45     2019_MVVNL_375210_1                                    74/EDCB/2019-20
# ...                    ...                                                ...
# 51988  2020_UPRNS_443277_1                           1112/E-Nivida/LucknowIII
# 52011  2020_UPRNS_445487_1         1376/NIVIDA/UPRNSS/GKP/2019-20 DT-07.03.20
# ...

# %%
all_sum = up_tenders['Awarded Value'].sum()
all_sum
# Out:
# np.float64(25847637713.246998)

# %%
flood_tenders_all = pd.read_csv(r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Sources/TENDERS/data/flood_tenders_all.csv')

# %%
flood_tenders_all = flood_tenders_all.loc[flood_tenders_all['Status'] == 'Accepted-AOC']
sum = flood_tenders_all['Awarded Value'].str.replace(',','').astype(float).sum()
sum
# Out:
# np.float64(2176259930.131)

# %%
flood_tenders_all
# Out:
#                   Tender ID  \
# 3       2019_CEUAZ_374005_1
# 4     2025_UPIDC_1083668_59
# 5      2025_UPIDC_1083216_1
# 6     2025_UPIDC_1086698_10
# 7     2025_UPIDC_1088427_94
# ...                     ...
# 5169    2020_CEUCZ_427563_1
# 5170    2020_CEUFZ_439158_1
# 5171    2020_SCIDC_445400_1
# 5172    2020_UPIDC_426781_9
# 5173    2020_UPJNM_434564_1
#
#                                tender_externalreference  \
# 3     2111 /SE Tender/Azamgarh Circle /19 DT. 09/08/...
# 4                                         01/EE/2025-26
# 5                        02 Date 08.10.2025 (Lot No-02)
# 6                                      04/AE-IV/2025-26
# 7                                         01/AE/2025-26
# ...                                                 ...
# 5169                 367/e-tender/2020 dated 23.01.2020
# 5170    1053/2com Ayo.Ambe.Circle/2020 Dated 24.02.2020
# 5171                                86/76/MLC/Firozabad
# ...
