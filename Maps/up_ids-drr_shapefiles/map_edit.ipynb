# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
up_villages = gpd.read_file('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_Villages_Boundary_Simplified.geojson')

# %%
up_villages = up_villages.drop(columns=['geometry','remark', 'ac_no', 'search_village',
       'st_length(shape)', 'st_area(shape)' ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 up_villages = up_villages.drop(columns=['geometry','remark', 'ac_no', 'search_village',
#       2        'st_length(shape)', 'st_area(shape)' ])
#
# NameError: name 'up_villages' is not defined

# %%
up_villages.to_csv('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_VILLAGES.csv', index=False
                   )

# %% [markdown]
# ### Convert shapefile CRS

# %%
up_dt = gpd.read_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Maps\up_ids-drr_shapefiles\UP_district_final.geojson')

# %%
import geopandas as gpd

# 1. Read your “meter‐based” GeoJSON
gdf = gpd.read_file(r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Maps\up_ids-drr_shapefiles\UP_Subdistrict_final_modified.geojson")

# 2. Tell GeoPandas it’s in Web Mercator
gdf = gdf.set_crs(epsg=3857)

# 3. Reproject to WGS84 (lat/lon)
gdf = gdf.to_crs(epsg=4326)

# 4. Save out a new GeoJSON with decimal‐degree coords
gdf.to_file(r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Maps\up_ids-drr_shapefiles\UP_subdistrict_final_4326.geojson", driver="GeoJSON")

# %% [markdown]
# ### Create UP district object-id reference

# %%
up_sdt = gpd.read_file('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_Subdistrict_final_modified.geojson')

# %%
up_sdt
# Out:
#         object_id         stname          dtname      sdtname  st_area_sh  \
# 0    09-168-00865  UTTAR PRADESH        Hamirpur         Rath         0.0
# 1    09-200-01005  UTTAR PRADESH       Sonbhadra  Robertsganj         0.0
# 2    09-177-00902  UTTAR PRADESH         Ayodhya      Rudauli         0.0
# 3    09-185-00940  UTTAR PRADESH           Basti     Rudhauli         0.0
# 4    09-190-00960  UTTAR PRADESH          Deoria     Rudrapur         0.0
# ..            ...            ...             ...          ...         ...
# 311  09-139-00737  UTTAR PRADESH         Baghpat      Khekada         0.0
# 312  09-137-00718  UTTAR PRADESH          Amroha        Kanth         0.0
# 313  09-202-01011  UTTAR PRADESH         Kasganj      Sahawar         0.0
# 314  09-178-00911  UTTAR PRADESH  Ambedkar Nagar        Bhiti         0.0
# 315  09-173-00884  UTTAR PRADESH      Pratapgarh     Raniganj         0.0
#
#      st_length_ remarks  dist_lgd  state_lgd  subdt_lgd  ac_no  \
# ...

# %%
# create the district geojson
up_district = up_sdt.dissolve(by='dtname', as_index=False)

# %%
up_district.to_file('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_district_final.geojson')

# %%
up_district['object-id'] = up_district['object_id'].str[:6]
up_district_asset = up_district[['object-id','dtname']]
up_district_asset.to_csv('/Users/saurabhlevin/Deployment/IDS-DRR-Uttar-Pradesh-Flood-Risk-Model/RiskScoreModel/assets/district_objectid.csv')
